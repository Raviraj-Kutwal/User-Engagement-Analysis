# %% [markdown]
# <a href="https://colab.research.google.com/github/Raviraj-Kutwal/User-Engagement-Analysis/blob/main/Raviraj_Kutwal_Computer_Dept.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# creating data-frame:

data =pd.read_excel('UserEngagementSurvey.xlsx')

# %%
data
# Out:
#                         Timestamp  \
# 0    2024/12/24 11:33:49 AM GMT+8
# 1    2024/12/24 11:33:49 AM GMT+8
# 2    2024/12/24 11:33:49 AM GMT+8
# 3    2024/12/24 11:33:49 AM GMT+8
# 4    2024/12/24 11:33:49 AM GMT+8
# ..                            ...
# 146  2024/12/26 11:05:59 AM GMT+8
# 147  2024/12/26 11:05:59 AM GMT+8
# 148  2024/12/26 11:05:59 AM GMT+8
# 149  2024/12/26 11:06:00 AM GMT+8
# 150  2024/12/26 11:06:00 AM GMT+8
#
#     By clicking 'I agree' below, you are indicating that you have read and understood this consent form and agree to participate in this research study. If you are under 18 years old, you confirm that you have obtained parental or guardian consent to participate.   \
# 0                                                Agree
# 1                                                Agree
# 2                                                Agree
# 3                                                Agree
# 4                                                Agree
# ...

# %%
#EDA:

# %%
#viewing the first 5 records of dataset
data.head(5)
# Out:
#                       Timestamp  \
# 0  2024/12/24 11:33:49 AM GMT+8
# 1  2024/12/24 11:33:49 AM GMT+8
# 2  2024/12/24 11:33:49 AM GMT+8
# 3  2024/12/24 11:33:49 AM GMT+8
# 4  2024/12/24 11:33:49 AM GMT+8
#
#   By clicking 'I agree' below, you are indicating that you have read and understood this consent form and agree to participate in this research study. If you are under 18 years old, you confirm that you have obtained parental or guardian consent to participate.   \
# 0                                              Agree
# 1                                              Agree
# 2                                              Agree
# 3                                              Agree
# 4                                              Agree
#
#   What is your age? What is your gender? What is your occupation?  \
# 0          Under 18               Female                 Employed
# 1           25 - 34               Female            Self-employed
# ...

# %%
#viewing the last 5 records of the data
data.tail(5)
# Out:
#                         Timestamp  \
# 146  2024/12/26 11:05:59 AM GMT+8
# 147  2024/12/26 11:05:59 AM GMT+8
# 148  2024/12/26 11:05:59 AM GMT+8
# 149  2024/12/26 11:06:00 AM GMT+8
# 150  2024/12/26 11:06:00 AM GMT+8
#
#     By clicking 'I agree' below, you are indicating that you have read and understood this consent form and agree to participate in this research study. If you are under 18 years old, you confirm that you have obtained parental or guardian consent to participate.   \
# 146                                              Agree
# 147                                              Agree
# 148                                              Agree
# 149                                              Agree
# 150                                              Agree
#
#     What is your age? What is your gender? What is your occupation?  \
# 146           45 - 54               Female            Self-employed
# 147           18 - 24               Female                  Student
# ...

# %%
#understanding the dataset:
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 151 entries, 0 to 150
# Data columns (total 20 columns):
#  #   Column                                                                                                                                                                                                                                                                Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                                                                                --------------  -----
#  0   Timestamp                                                                                                                                                                                                                                                             151 non-null    object
# ...

# %%
# viewing the dimensions of the dataset
data.shape
# Out:
# (151, 20)

# %%
#dataset has 151 records(rowsw),and 20 columns

# %%
#using data.describe function to undersatand the column values
data.describe()
# Out:
#        How often do you interact with participating in online discussions on websites?  \
# count                                         151.000000
# mean                                            3.019868
# std                                             1.202609
# min                                             1.000000
# 25%                                             2.000000
# 50%                                             3.000000
# 75%                                             4.000000
# max                                             5.000000
#
#        How satisfied are you with the overall user experience of Malaysian web platforms? (Rate on a scale of 1-5, where 1 is 'Very Dissatisfied' and 5 is 'Very Satisfied')   \
# count                                         151.000000
# mean                                            3.178808
# std                                             1.233348
# min                                             1.000000
# ...

# %%
#using data.isnull function to view null values
data.isnull()
# Out:
#      Timestamp  \
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# ..         ...
# 146      False
# 147      False
# 148      False
# 149      False
# 150      False
#
#      By clicking 'I agree' below, you are indicating that you have read and understood this consent form and agree to participate in this research study. If you are under 18 years old, you confirm that you have obtained parental or guardian consent to participate.   \
# 0                                                False
# 1                                                False
# 2                                                False
# 3                                                False
# 4                                                False
# ..                                                 ...
# 146                                              False
# 147                                              False
# 148                                              False
# ...

# %%
#using .sum() with isnull to simplify
data.isnull().sum()
# Out:
# Timestamp                                                                                                                                                                                                                                                                0
# By clicking 'I agree' below, you are indicating that you have read and understood this consent form and agree to participate in this research study. If you are under 18 years old, you confirm that you have obtained parental or guardian consent to participate.      0
# What is your age?                                                                                                                                                                                                                                                        0
# ...

# %%
#viewing the datatypes of the columns
data.dtypes
# Out:
# Timestamp                                                                                                                                                                                                                                                               object
# By clicking 'I agree' below, you are indicating that you have read and understood this consent form and agree to participate in this research study. If you are under 18 years old, you confirm that you have obtained parental or guardian consent to participate.     object
# What is your age?                                                                                                                                                                                                                                                       object
# ...

# %%
# data cleaning and Preprocessing

# %%
#deleting useless columns
data = data.rename(columns={data.columns[1]: 'Consent'})# changed the name of column then deleted the column
data = data.drop(['Timestamp', 'Consent'], axis=1)

# %%
data.head()
# Out:
#   What is your age? What is your gender? What is your occupation?  \
# 0          Under 18               Female                 Employed
# 1           25 - 34               Female            Self-employed
# 2           55 - 64               Female                  Retired
# 3           55 - 64               Female               Unemployed
# 4      65 and above                 Male               Unemployed
#
#   How often do you use the internet?  \
# 0              Several times a month
# 1                             Rarely
# 2                       Once a month
# 3                             Rarely
# 4              Several times a month
#
#   Which device do you primarily use to access the internet?  \
# 0                                             Laptop
# 1                                             Laptop
# 2                                         Smartphone
# 3                                             Tablet
# 4                                             Laptop
#
# ...

# %%
# renaming all columns to a shorter name to simplify working with dataset
data.rename(columns={
    'What is your age?': 'age',
    'What is your gender?': 'gender',
    'What is your occupation?': 'occupation',
    'How often do you use the internet?':'internet_usage',
    'Which device do you primarily use to access the internet?':'device',
    'What is your main reason for using the internet?':'reason',
    'What types of Malaysian web platforms do you frequently visit?':'webplatform_types',
    'How often do you interact with online shopping on websites?':'for_online_shopping',
    'How often do you interact with reading articles on websites?':'for_reading_articles',
    'How often do you interact with watching videos on websites?':'for_watching_videos',
    'How often do you interact with participating in online discussions on websites?':'for_online_discussions',
    'How often do you interact with social media integration on websites?':'social_media_integration',
    "How satisfied are you with the overall user experience of Malaysian web platforms? (Rate on a scale of 1-5, where 1 is 'Very Dissatisfied' and 5 is 'Very Satisfied') ":'overall_experience',
    'How likely are you to recommend Malaysian web platforms to others? (Rate on a scale of 1-5, where 1 is \'Very Unlikely\' and 5 is \'Very Likely\')':'will_recommend',
    'How accessible do you find Malaysian web platforms for people with disabilities? (Rate on a scale of 1-5, where 1 is \'Not Accessible at All\' and 5 is \'Very Accessible\')':'accessiblity_for_disable',
    'How successful are you at finding what you need on Malaysian web platforms? (Rate on a scale of 1-5, where 1 is \'Never Successful\' and 5 is \'Always Successful\')':'rating_for_finding_needs',
    "What improvements would you suggest for Malaysian web platforms to enhance your experience? ":'improvements',
    'Are there any additional features you would like to see implemented on Malaysian web platforms?':'additional_features'
}, inplace=True)

data.head()
# Out:
#             age  gender     occupation         internet_usage      device  \
# 0      Under 18  Female       Employed  Several times a month      Laptop
# 1       25 - 34  Female  Self-employed                 Rarely      Laptop
# 2       55 - 64  Female        Retired           Once a month  Smartphone
# 3       55 - 64  Female     Unemployed                 Rarely      Tablet
# 4  65 and above    Male     Unemployed  Several times a month      Laptop
#
#          reason    webplatform_types for_online_shopping for_reading_articles  \
# 0     Education  Government services                   4            1 (Never)
# 1          Work         News portals                   3                    2
# 2  Social Media  Government services                   4                    2
# 3  Social Media           E-commerce                   3                    2
# 4  Social Media    Educational sites                   2                    2
#
# ...

# %%
# checking null values
data.isnull().sum()
# Out:
# age                          0
# gender                       0
# occupation                   0
# internet_usage               0
# device                       0
# reason                       0
# webplatform_types            0
# for_online_shopping          0
# for_reading_articles         0
# for_watching_videos          0
# for_online_discussions       0
# social_media_integration     0
# overall_experience           0
# will_recommend               0
# accessiblity_for_disable     0
# rating_for_finding_needs     0
# improvements                39
# additional_features         39
# dtype: int64

# %%
# replacing null values at 'improvements','additional_features' with NaN
data['improvements'].replace(np.nan, 'NaN', inplace=True)
data['additional_features'].replace(np.nan, 'NaN', inplace=True)

# %%
data.isnull().sum()
# Out:
# age                         0
# gender                      0
# occupation                  0
# internet_usage              0
# device                      0
# reason                      0
# webplatform_types           0
# for_online_shopping         0
# for_reading_articles        0
# for_watching_videos         0
# for_online_discussions      0
# social_media_integration    0
# overall_experience          0
# will_recommend              0
# accessiblity_for_disable    0
# rating_for_finding_needs    0
# improvements                0
# additional_features         0
# dtype: int64

# %%
data.age.value_counts()
# Out:
# age
# 25 - 34         31
# 45 - 54         27
# 55 - 64         26
# 18 - 24         20
# Under 18        18
# 35 - 44         18
# 65 and above    11
# Name: count, dtype: int64

# %%
#removing under 18 and above 65
data['age'] = data['age'].map({'Under 18': '0-18', '18 - 24': '18-24','25 - 34':'25-34','35 - 44':'35-44',
                               '45 - 54':'45-54',
                               '55 - 64':'55-64',
                              '65 and above':'65-100'})

# %%
data['age'].head(5)
# Out:
# 0      0-18
# 1     25-34
# 2     55-64
# 3     55-64
# 4    65-100
# Name: age, dtype: object

# %%
#Sorting according to age
data.age.value_counts().sort_index()
# Out:
# age
# 0-18      18
# 18-24     20
# 25-34     31
# 35-44     18
# 45-54     27
# 55-64     26
# 65-100    11
# Name: count, dtype: int64

# %%
data
# Out:
#         age  gender     occupation         internet_usage      device  \
# 0      0-18  Female       Employed  Several times a month      Laptop
# 1     25-34  Female  Self-employed                 Rarely      Laptop
# 2     55-64  Female        Retired           Once a month  Smartphone
# 3     55-64  Female     Unemployed                 Rarely      Tablet
# 4    65-100    Male     Unemployed  Several times a month      Laptop
# ..      ...     ...            ...                    ...         ...
# 146   45-54  Female  Self-employed                  Daily     Desktop
# 147   18-24  Female        Student            Once a week     Desktop
# 148   55-64    Male       Employed  Several times a month     Desktop
# 149   25-34  Female        Student           Once a month      Tablet
# 150   55-64  Female        Retired           Once a month      Tablet
#
#                    reason    webplatform_types for_online_shopping  \
# ...

# %%
data['for_online_shopping'].value_counts()
# Out:
# for_online_shopping
# 4             42
# 2             38
# 3             36
# 1 (Never)     18
# 5 (Always)    17
# Name: count, dtype: int64

# %%
data['for_online_shopping'].value_counts()
# Out:
# for_online_shopping
# 4             42
# 2             38
# 3             36
# 1 (Never)     18
# 5 (Always)    17
# Name: count, dtype: int64

# %%
data['for_online_shopping'].map(type)
# Out:
# 0      <class 'int'>
# 1      <class 'int'>
# 2      <class 'int'>
# 3      <class 'int'>
# 4      <class 'int'>
#            ...
# 146    <class 'int'>
# 147    <class 'str'>
# 148    <class 'int'>
# 149    <class 'str'>
# 150    <class 'int'>
# Name: for_online_shopping, Length: 151, dtype: object

# %%
#removing the str type values
data['for_online_shopping'] = data['for_online_shopping'].map({'1 (Never)': 1, 2:2, 3:3, 4:4 , '5 (Always)':5})
data['for_reading_articles'] = data['for_reading_articles'].map({'1 (Never)': 1, 2:2, 3:3, 4:4 , '5 (Always)':5})
data['for_watching_videos'] = data['for_watching_videos'].map({'1 (Never)': 1, 2:2, 3:3, 4:4 , 5:5})
data['social_media_integration'] = data['social_media_integration'].map({'1 (Never)': 1, 2:2, 3:3, 4:4 , 5:5})

# %%
data
# Out:
#         age  gender     occupation         internet_usage      device  \
# 0      0-18  Female       Employed  Several times a month      Laptop
# 1     25-34  Female  Self-employed                 Rarely      Laptop
# 2     55-64  Female        Retired           Once a month  Smartphone
# 3     55-64  Female     Unemployed                 Rarely      Tablet
# 4    65-100    Male     Unemployed  Several times a month      Laptop
# ..      ...     ...            ...                    ...         ...
# 146   45-54  Female  Self-employed                  Daily     Desktop
# 147   18-24  Female        Student            Once a week     Desktop
# 148   55-64    Male       Employed  Several times a month     Desktop
# 149   25-34  Female        Student           Once a month      Tablet
# 150   55-64  Female        Retired           Once a month      Tablet
#
#                    reason    webplatform_types  for_online_shopping  \
# ...

# %%
#dataset is now ready for visualization

# %%
#DATA VISUALIZATION

# %%
# Responses based on age
age = data['age'].value_counts(ascending=True)
ax = sns.barplot(x=age.index, y=age.values, order=age.index,color='green')
ax.set(xlabel='AGE', yticks=[], title='Responses based on age', frame_on=False)
ax.tick_params(length=0)
ax.bar_label(ax.containers[0])
plt.show()

# %%
# RESPONSES BASED ON GENDER OF PARTICIPANTS OF SURVEY
colors = ['#eca9f4', '#70d3fb']
data.groupby('gender').size().plot(kind='pie', colors=colors, autopct='%1.1f%%', startangle=90)
plt.title('RESPONSES BASED ON GENDER OF PARTICIPANTS OF SURVEY')
plt.show()

# %%
# OCCUPATION OF SURVEY PARTICIPANTS
sns.countplot(x='occupation',hue='gender',data=data)
plt.title("OCCUPATION OF SURVEY PARTICIPANTS")
plt.show()

# %%
# HOW OFTEN THE PARTICIPANTS OF SURVEY USE THE INTERNET
data['internet_usage'].value_counts()
sns.countplot(x='internet_usage',data=data)
plt.title("HOW OFTEN THE PARTICIPANTS OF SURVEY USE THE INTERN")
plt.xticks(rotation=90)
plt.show()

# %%
#THE DEVICES USED FOR BROWSING INTERNET
colors = ['r','c','g','m']
data.groupby('device').size().plot(kind='pie', colors=colors, autopct='%1.1f%%', startangle=0)
plt.title('THE DEVICES USED FOR BROWSING INTERNET')
plt.show()

# %%
fig, axarr = plt.subplots(2, 2, figsize=(10, 10))

data['for_online_shopping'].value_counts().plot.pie(ax=axarr[0, 0],autopct='%1.1f%%')
axarr[0, 0].set_title("For Online Shopping")

data['for_reading_articles'].value_counts().plot.pie(ax=axarr[0, 1], autopct='%1.1f%%')
axarr[0, 1].set_title("For Reading Articles")

data['for_watching_videos'].value_counts().plot.pie(ax=axarr[1, 0], autopct='%1.1f%%')
axarr[1, 0].set_title("For Watching Videos")



data['for_online_discussions'].value_counts().plot.pie(ax=axarr[1, 1], autopct='%1.1f%%')
axarr[1, 1].set_title("For Online Discussions")

plt.subplots_adjust(hspace=0, wspace=0)
plt.legend(loc='lower right')

plt.show()

# %%
data.head(2)
# Out:
#      age  gender     occupation         internet_usage  device     reason  \
# 0   0-18  Female       Employed  Several times a month  Laptop  Education
# 1  25-34  Female  Self-employed                 Rarely  Laptop       Work
#
#      webplatform_types  for_online_shopping  for_reading_articles  \
# 0  Government services                    4                     1
# 1         News portals                    3                     2
#
#    for_watching_videos  for_online_discussions  social_media_integration  \
# 0                    1                       3                         2
# 1                    3                       4                         2
#
#    overall_experience  will_recommend  accessiblity_for_disable  \
# 0                   4               4                         3
# 1                   3               4                         3
#
#    rating_for_finding_needs improvements additional_features
# ...

# %%
#WEBSITE ACESSIBILITY FOR DISABLED PEOPLE
data['accessiblity_for_disable'].value_counts(ascending=True).plot.bar(color='orange' )
plt.style.use('fivethirtyeight')
plt.title('WEBSITE ACESSIBILITY FOR DISABLED PEOPLE')
plt.xlabel("Rating")
plt.ylabel("Count")
plt.xticks(rotation=360)
plt.show()

# %%
#OVERALL EXPERIENCE OF WEBSITE USERS
data['overall_experience'].value_counts(ascending=True).plot.bar( )
plt.style.use('fivethirtyeight')
plt.title('OVERALL EXPERIENCE OF WEBSITE USERS')
plt.xlabel("Rating")
plt.ylabel("Count")
plt.xticks(rotation=360)
plt.show()

# %%
# IMPROVEMENTS SUGGESTED BY SURVEY PARTICIPANTS
data['improvements'].value_counts(ascending=True).plot.bar( )
plt.style.use('ggplot')
plt.title('IMPROVEMENTS SUGGESTED BY SURVEY PARTICIPANTS')
plt.xlabel("Suggestions")
plt.ylabel("Count")
plt.xticks(rotation=90)

plt.title('IMPROVEMENTS SUGGESTED BY SURVEY PARTICIPANTS')

plt.show()

# %%
# WOULD THE USERS RECOMMEND USING THE WEBSITES
data['will_recommend'].value_counts(ascending=True).plot.pie(color='green',autopct='%1.1f%%', startangle=0)

plt.title('WOULD THE USERS RECOMMEND USING THE WEBSITES')


plt.show()

# %%
# ADDITIONAL FEATURES REQUESTED BY USERS ,TO BE ADDED TO WEBSITES
data['additional_features'].value_counts(ascending=True).plot.bar( )
plt.style.use('ggplot')
plt.title('ADDITIONAL FEATURES REQUESTED BY USERS ,TO BE ADDED TO WEBSITES')
plt.xlabel("FEATURES")
plt.ylabel("Count")
plt.xticks(rotation=90)

plt.title('IMPROVEMENTS SUGGESTED BY SURVEY PARTICIPANTS')

plt.show()
